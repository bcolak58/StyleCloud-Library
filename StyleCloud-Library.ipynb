# %% [markdown]
# # Style Cloud-Library

# %%
#!pip install stylecloud

# %%
import stylecloud as sc

# %%
sc.gen_stylecloud(file_path='challenge.txt',output_name='ch.png')

# %%
from IPython.display import Image #resim göstermek için kullanılır
Image('ch.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-car',
    background_color='blue',
    output_name='ch2.png')
Image('ch2.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-truck',
    output_name='ch3.png')
Image('ch3.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-fighter-jet',
    output_name='ch4.png')
Image('ch4.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-star-and-crescent',
    output_name='tr.png')
Image('tr.png')
